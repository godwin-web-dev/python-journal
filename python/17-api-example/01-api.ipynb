# %%
import requests
api_url='https://apigtwyapps-ext-stg.netapp.com/aiq/smso_stg/api/v1/Subscription'
def subscription_response():
    try:
        application_header={'authorization':'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IlJnYjVRbldCZHZ5YmFmbk9uM0tXSF9Zamh0SjBRa05IYjAxQndsV3BrT0EiLCJ0eXAiOiJKV1QifQ.....rCEJofnfUTIXXhBljScma4cgHpTi5tSL0JrnwlmYG85OLu3x4I_csC7q2VFn-Q8kxfBZZrT-6krXpULwhl_JeDw2XTeRiQ0TBA5A2-4HZW08JS9d_PT2IA17CPpllZea8m3RvfB6iNBhvJG92MeBefFuQ8JgB8erfFA2GS5-DRBMDVDAGYCZ2fX3rhWQTlwnPf9lv984tlSIMasx4Phj-PpMkuQH4DUSHpne8dQeZUkVfXnIj88kdZsLXi5jgYJGlVth7AOIuwRozy-rzDWfJxfrjeZqHGSJ5bzMl3R6e8GIBiyfIZ1dtI2r_0U9UCPgcA8CLJlh3PW-tRlVl9wOWw'}
        response=requests.get(api_url,headers=application_header)
        response.raise_for_status()
        result=response.json()
        user_notes=[]
        serial_number=[]
        system_id=[]
        for i in result:
            user_notes.append(i.get('user_note'))
            serial_number.append(i.get('serial_number'))
            system_id.append(i.get('serial_number'))
        print("user_notes ==> ",user_notes)
        print("serial_number ==> ",serial_number)
        print("system_id  ==> ",system_id)
    except requests.RequestException as e:
        print("Failed to fetch data ",e)
subscription_response()
# Out:
# user_notes ==>  ['subscription test 001', 'subscription test sample 000001', 'test', 'test__subject__001', 'test__subject__002', 'test__subject__003', 'test__subject_004', 'batman', 'ironman', 'superman', 'thanos', 'joker']
# serial_number ==>  ['792401000626', '952408000613', '952416000284', 'UNKNOWN', 'b999999999', 'J302DT0C', '4211662-91-5', '451716000029', '621606000029', '952422000534', '651904000285', '952213000887']
# system_id  ==>  ['792401000626', '952408000613', '952416000284', 'UNKNOWN', 'b999999999', 'J302DT0C', '4211662-91-5', '451716000029', '621606000029', '952422000534', '651904000285', '952213000887']
